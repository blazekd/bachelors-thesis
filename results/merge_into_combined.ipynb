# %%
import pandas as pd
import os
import glob
  
import os
if os.path.exists("combined.csv"):
  os.remove("combined.csv")
    
  
# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
dfres =pd.DataFrame(columns = ['test', 'algorithm', 'less', 'my_compare', 'slow_compare', 'sorted', 'stable', 'compare_count'])
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f, sep=';', header=None)
    df.columns = ['test', 'algorithm', 'less', 'my_compare', 'slow_compare', 'sorted', 'stable', 'compare_count']
    # print the location and filename
    #print('Location:', f)
    #print('File Name:', f.split("\\")[-1])
      
    # print the content
    #print('Content:')
    #display(df)
    #pd.concat([dfres, df], axis=1)
    dfres = pd.concat([dfres, df], ignore_index=True)

    #print()
    
dfgrouped = dfres.groupby(['test','algorithm'], 
                  as_index=False).mean()
display(dfgrouped)
dfgrouped.to_csv('combined.csv', sep=';', index=False)
# Out:
#                                test               algorithm     less
# 0       test/largeclass_rng_5000.in            gfx::timsort   1829.6  \
# 1       test/largeclass_rng_5000.in         it_merge_2_sort   2512.6
# 2       test/largeclass_rng_5000.in     it_merge_2_sort_rev   2446.8
# 3       test/largeclass_rng_5000.in         it_merge_3_sort   2252.8
# 4       test/largeclass_rng_5000.in        it_merge_4a_sort   2282.8
# ...                             ...                     ...      ...
# 2123  test/string_sorted_5000000.in  timsort_parallel_b_20c  49624.6
# 2124  test/string_sorted_5000000.in   timsort_parallel_b_2c  39749.4
# 2125  test/string_sorted_5000000.in   timsort_parallel_b_4c  39923.4
# 2126  test/string_sorted_5000000.in   timsort_parallel_b_8c  48653.8
# 2127  test/string_sorted_5000000.in             timsort_rev  39979.0
#
#      my_compare slow_compare sorted stable compare_count
# 0        1732.8       2744.8    1.0    1.0       55136.0
# ...
